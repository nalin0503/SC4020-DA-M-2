# %%
import pandas as pd
import numpy as np
from scipy.special import softmax
import torch

# %%
data = pd.read_csv("data/POIdata_cityA.csv")
data.head()
# Out:
#    x  y  category  POI_count
# 0  1  1        74          4
# 1  1  1        48          4
# 2  1  1        79          2
# 3  1  1        69          2
# 4  1  1        73          1

# %%
x_scaled = np.ceil(data[["x", ]] / 10)
x_scaled = x_scaled.astype("int")
y_scaled = np.ceil(data[["y", ]] / 10)
y_scaled = y_scaled.astype("int")

data["x"] = x_scaled
data["y"] = y_scaled

# %%
checked = []
city = pd.DataFrame(columns = data.columns)

for x, y in zip(data["x"], data["y"]):
    if (x, y) in checked:
        continue

    print(f"Aggregating ({x}, {y}) coordinates.")
    filtered_data = data[(data["x"] == x) & (data["y"] == y)]
    aggregated_data = filtered_data.groupby("category", as_index = False)["POI_count"].sum()
    aggregated_data["x"] = [x] * len(aggregated_data)
    aggregated_data["y"] = [y] * len(aggregated_data)

    city = pd.concat([city, aggregated_data[city.columns]], ignore_index = True)
    
    checked.append((x, y))

city
# Out:
# Aggregating (1, 1) coordinates.
# Aggregating (1, 2) coordinates.
# Aggregating (1, 3) coordinates.
# Aggregating (1, 4) coordinates.
# Aggregating (1, 5) coordinates.
# Aggregating (1, 6) coordinates.
# Aggregating (1, 7) coordinates.
# Aggregating (1, 8) coordinates.
# Aggregating (1, 9) coordinates.
# Aggregating (1, 10) coordinates.
# Aggregating (2, 1) coordinates.
# Aggregating (2, 2) coordinates.
# Aggregating (2, 3) coordinates.
# Aggregating (2, 4) coordinates.
# Aggregating (2, 10) coordinates.
# Aggregating (2, 11) coordinates.
# Aggregating (2, 12) coordinates.
# Aggregating (2, 13) coordinates.
# Aggregating (2, 14) coordinates.
# Aggregating (3, 1) coordinates.
# Aggregating (3, 2) coordinates.
# Aggregating (3, 11) coordinates.
# Aggregating (3, 12) coordinates.
# Aggregating (3, 14) coordinates.
# Aggregating (3, 13) coordinates.
# Aggregating (3, 15) coordinates.
# Aggregating (3, 16) coordinates.
# Aggregating (3, 17) coordinates.
# Aggregating (4, 1) coordinates.
# Aggregating (4, 12) coordinates.
# Aggregating (4, 13) coordinates.
# Aggregating (4, 14) coordinates.
# Aggregating (4, 15) coordinates.
# Aggregating (4, 16) coordinates.
# Aggregating (4, 17) coordinates.
# Aggregating (4, 18) coordinates.
# Aggregating (4, 19) coordinates.
# Aggregating (4, 2) coordinates.
# Aggregating (4, 11) coordinates.
# Aggregating (4, 20) coordinates.
# Aggregating (4, 10) coordinates.
# Aggregating (5, 1) coordinates.
# Aggregating (5, 9) coordinates.
# Aggregating (5, 10) coordinates.
# Aggregating (5, 11) coordinates.
# Aggregating (5, 15) coordinates.
# Aggregating (5, 16) coordinates.
# Aggregating (5, 17) coordinates.
# Aggregating (5, 18) coordinates.
# Aggregating (5, 19) coordinates.
# Aggregating (5, 20) coordinates.
# Aggregating (5, 8) coordinates.
# Aggregating (5, 12) coordinates.
# Aggregating (6, 1) coordinates.
# Aggregating (6, 7) coordinates.
# Aggregating (6, 8) coordinates.
# Aggregating (6, 9) coordinates.
# Aggregating (6, 17) coordinates.
# Aggregating (6, 18) coordinates.
# Aggregating (6, 19) coordinates.
# Aggregating (6, 20) coordinates.
# Aggregating (6, 14) coordinates.
# Aggregating (6, 11) coordinates.
# Aggregating (6, 12) coordinates.
# Aggregating (6, 13) coordinates.
# Aggregating (6, 2) coordinates.
# Aggregating (6, 15) coordinates.
# Aggregating (7, 1) coordinates.
# Aggregating (7, 2) coordinates.
# Aggregating (7, 8) coordinates.
# Aggregating (7, 9) coordinates.
# Aggregating (7, 11) coordinates.
# Aggregating (7, 12) coordinates.
# Aggregating (7, 13) coordinates.
# Aggregating (7, 14) coordinates.
# Aggregating (7, 17) coordinates.
# Aggregating (7, 18) coordinates.
# Aggregating (7, 19) coordinates.
# Aggregating (7, 20) coordinates.
# Aggregating (7, 15) coordinates.
# Aggregating (7, 16) coordinates.
# Aggregating (7, 10) coordinates.
# Aggregating (7, 3) coordinates.
# Aggregating (7, 7) coordinates.
# Aggregating (8, 1) coordinates.
# Aggregating (8, 2) coordinates.
# Aggregating (8, 3) coordinates.
# Aggregating (8, 7) coordinates.
# Aggregating (8, 8) coordinates.
# Aggregating (8, 9) coordinates.
# Aggregating (8, 10) coordinates.
# Aggregating (8, 11) coordinates.
# Aggregating (8, 12) coordinates.
# Aggregating (8, 13) coordinates.
# Aggregating (8, 14) coordinates.
# Aggregating (8, 15) coordinates.
# Aggregating (8, 17) coordinates.
# Aggregating (8, 18) coordinates.
# Aggregating (8, 19) coordinates.
# Aggregating (8, 20) coordinates.
# Aggregating (8, 16) coordinates.
# Aggregating (9, 1) coordinates.
# Aggregating (9, 2) coordinates.
# Aggregating (9, 3) coordinates.
# Aggregating (9, 7) coordinates.
# Aggregating (9, 8) coordinates.
# Aggregating (9, 9) coordinates.
# Aggregating (9, 10) coordinates.
# Aggregating (9, 11) coordinates.
# Aggregating (9, 12) coordinates.
# Aggregating (9, 13) coordinates.
# Aggregating (9, 14) coordinates.
# Aggregating (9, 15) coordinates.
# Aggregating (9, 16) coordinates.
# Aggregating (9, 17) coordinates.
# Aggregating (9, 18) coordinates.
# Aggregating (9, 20) coordinates.
# Aggregating (9, 19) coordinates.
# Aggregating (9, 4) coordinates.
# Aggregating (10, 1) coordinates.
# Aggregating (10, 2) coordinates.
# Aggregating (10, 3) coordinates.
# Aggregating (10, 7) coordinates.
# Aggregating (10, 8) coordinates.
# Aggregating (10, 9) coordinates.
# Aggregating (10, 10) coordinates.
# Aggregating (10, 11) coordinates.
# Aggregating (10, 12) coordinates.
# Aggregating (10, 13) coordinates.
# Aggregating (10, 14) coordinates.
# Aggregating (10, 15) coordinates.
# Aggregating (10, 16) coordinates.
# Aggregating (10, 18) coordinates.
# Aggregating (10, 19) coordinates.
# Aggregating (10, 17) coordinates.
# Aggregating (10, 20) coordinates.
# Aggregating (10, 4) coordinates.
# Aggregating (11, 1) coordinates.
# Aggregating (11, 2) coordinates.
# Aggregating (11, 3) coordinates.
# Aggregating (11, 4) coordinates.
# Aggregating (11, 7) coordinates.
# Aggregating (11, 8) coordinates.
# Aggregating (11, 9) coordinates.
# Aggregating (11, 10) coordinates.
# Aggregating (11, 11) coordinates.
# Aggregating (11, 12) coordinates.
# Aggregating (11, 13) coordinates.
# Aggregating (11, 14) coordinates.
# Aggregating (11, 15) coordinates.
# Aggregating (11, 16) coordinates.
# Aggregating (11, 17) coordinates.
# Aggregating (11, 19) coordinates.
# Aggregating (11, 18) coordinates.
# Aggregating (11, 20) coordinates.
# Aggregating (11, 5) coordinates.
# Aggregating (11, 6) coordinates.
# Aggregating (12, 1) coordinates.
# Aggregating (12, 2) coordinates.
# Aggregating (12, 3) coordinates.
# Aggregating (12, 4) coordinates.
# Aggregating (12, 5) coordinates.
# Aggregating (12, 6) coordinates.
# Aggregating (12, 7) coordinates.
# Aggregating (12, 8) coordinates.
# Aggregating (12, 9) coordinates.
# Aggregating (12, 10) coordinates.
# Aggregating (12, 11) coordinates.
# Aggregating (12, 12) coordinates.
# Aggregating (12, 13) coordinates.
# Aggregating (12, 14) coordinates.
# Aggregating (12, 15) coordinates.
# Aggregating (12, 16) coordinates.
# Aggregating (12, 17) coordinates.
# Aggregating (12, 18) coordinates.
# Aggregating (12, 20) coordinates.
# Aggregating (12, 19) coordinates.
# Aggregating (13, 1) coordinates.
# Aggregating (13, 2) coordinates.
# Aggregating (13, 3) coordinates.
# Aggregating (13, 4) coordinates.
# Aggregating (13, 5) coordinates.
# Aggregating (13, 6) coordinates.
# Aggregating (13, 7) coordinates.
# Aggregating (13, 8) coordinates.
# Aggregating (13, 9) coordinates.
# Aggregating (13, 10) coordinates.
# Aggregating (13, 11) coordinates.
# Aggregating (13, 12) coordinates.
# Aggregating (13, 13) coordinates.
# Aggregating (13, 14) coordinates.
# Aggregating (13, 15) coordinates.
# Aggregating (13, 16) coordinates.
# Aggregating (13, 17) coordinates.
# Aggregating (13, 20) coordinates.
# Aggregating (13, 18) coordinates.
# Aggregating (13, 19) coordinates.
# Aggregating (14, 1) coordinates.
# Aggregating (14, 3) coordinates.
# Aggregating (14, 4) coordinates.
# Aggregating (14, 5) coordinates.
# Aggregating (14, 6) coordinates.
# Aggregating (14, 7) coordinates.
# Aggregating (14, 8) coordinates.
# Aggregating (14, 9) coordinates.
# Aggregating (14, 10) coordinates.
# Aggregating (14, 11) coordinates.
# Aggregating (14, 12) coordinates.
# Aggregating (14, 13) coordinates.
# Aggregating (14, 14) coordinates.
# Aggregating (14, 15) coordinates.
# Aggregating (14, 16) coordinates.
# Aggregating (14, 17) coordinates.
# Aggregating (14, 18) coordinates.
# Aggregating (14, 19) coordinates.
# Aggregating (14, 20) coordinates.
# Aggregating (14, 2) coordinates.
# Aggregating (15, 1) coordinates.
# Aggregating (15, 3) coordinates.
# Aggregating (15, 4) coordinates.
# Aggregating (15, 5) coordinates.
# Aggregating (15, 6) coordinates.
# Aggregating (15, 7) coordinates.
# Aggregating (15, 8) coordinates.
# Aggregating (15, 9) coordinates.
# Aggregating (15, 10) coordinates.
# Aggregating (15, 11) coordinates.
# Aggregating (15, 12) coordinates.
# Aggregating (15, 13) coordinates.
# Aggregating (15, 14) coordinates.
# Aggregating (15, 15) coordinates.
# Aggregating (15, 17) coordinates.
# Aggregating (15, 18) coordinates.
# Aggregating (15, 19) coordinates.
# Aggregating (15, 20) coordinates.
# Aggregating (15, 16) coordinates.
# Aggregating (15, 2) coordinates.
# Aggregating (16, 2) coordinates.
# Aggregating (16, 3) coordinates.
# Aggregating (16, 4) coordinates.
# Aggregating (16, 5) coordinates.
# Aggregating (16, 6) coordinates.
# Aggregating (16, 7) coordinates.
# Aggregating (16, 8) coordinates.
# Aggregating (16, 9) coordinates.
# Aggregating (16, 10) coordinates.
# Aggregating (16, 11) coordinates.
# Aggregating (16, 12) coordinates.
# Aggregating (16, 13) coordinates.
# Aggregating (16, 14) coordinates.
# Aggregating (16, 15) coordinates.
# Aggregating (16, 16) coordinates.
# Aggregating (16, 17) coordinates.
# Aggregating (16, 19) coordinates.
# Aggregating (16, 20) coordinates.
# Aggregating (16, 18) coordinates.
# Aggregating (16, 1) coordinates.
# Aggregating (17, 1) coordinates.
# Aggregating (17, 2) coordinates.
# Aggregating (17, 3) coordinates.
# Aggregating (17, 4) coordinates.
# Aggregating (17, 5) coordinates.
# Aggregating (17, 6) coordinates.
# Aggregating (17, 7) coordinates.
# Aggregating (17, 8) coordinates.
# Aggregating (17, 9) coordinates.
# Aggregating (17, 10) coordinates.
# Aggregating (17, 11) coordinates.
# Aggregating (17, 12) coordinates.
# Aggregating (17, 13) coordinates.
# Aggregating (17, 14) coordinates.
# Aggregating (17, 15) coordinates.
# Aggregating (17, 16) coordinates.
# Aggregating (17, 17) coordinates.
# Aggregating (17, 18) coordinates.
# Aggregating (17, 19) coordinates.
# Aggregating (17, 20) coordinates.
# Aggregating (18, 1) coordinates.
# Aggregating (18, 2) coordinates.
# Aggregating (18, 3) coordinates.
# Aggregating (18, 4) coordinates.
# Aggregating (18, 5) coordinates.
# Aggregating (18, 6) coordinates.
# Aggregating (18, 7) coordinates.
# Aggregating (18, 8) coordinates.
# Aggregating (18, 9) coordinates.
# Aggregating (18, 10) coordinates.
# Aggregating (18, 11) coordinates.
# Aggregating (18, 12) coordinates.
# Aggregating (18, 13) coordinates.
# Aggregating (18, 14) coordinates.
# Aggregating (18, 15) coordinates.
# Aggregating (18, 16) coordinates.
# Aggregating (18, 17) coordinates.
# Aggregating (18, 18) coordinates.
# Aggregating (18, 19) coordinates.
# Aggregating (18, 20) coordinates.
# Aggregating (19, 1) coordinates.
# Aggregating (19, 2) coordinates.
# Aggregating (19, 3) coordinates.
# Aggregating (19, 4) coordinates.
# Aggregating (19, 5) coordinates.
# Aggregating (19, 6) coordinates.
# Aggregating (19, 7) coordinates.
# Aggregating (19, 8) coordinates.
# Aggregating (19, 9) coordinates.
# Aggregating (19, 10) coordinates.
# Aggregating (19, 11) coordinates.
# Aggregating (19, 12) coordinates.
# Aggregating (19, 13) coordinates.
# Aggregating (19, 14) coordinates.
# Aggregating (19, 15) coordinates.
# Aggregating (19, 16) coordinates.
# Aggregating (19, 17) coordinates.
# Aggregating (19, 18) coordinates.
# Aggregating (19, 20) coordinates.
# Aggregating (19, 19) coordinates.
# Aggregating (20, 1) coordinates.
# Aggregating (20, 2) coordinates.
# Aggregating (20, 3) coordinates.
# Aggregating (20, 4) coordinates.
# Aggregating (20, 5) coordinates.
# Aggregating (20, 6) coordinates.
# Aggregating (20, 7) coordinates.
# Aggregating (20, 8) coordinates.
# Aggregating (20, 9) coordinates.
# Aggregating (20, 10) coordinates.
# Aggregating (20, 11) coordinates.
# Aggregating (20, 12) coordinates.
# Aggregating (20, 13) coordinates.
# Aggregating (20, 14) coordinates.
# Aggregating (20, 15) coordinates.
# Aggregating (20, 16) coordinates.
# Aggregating (20, 17) coordinates.
# Aggregating (20, 18) coordinates.
# Aggregating (20, 19) coordinates.
# Aggregating (20, 20) coordinates.
#         x   y category POI_count
# 0       1   1        4        21
# 1       1   1        5         9
# 2       1   1        6         1
# 3       1   1        7         1
# 4       1   1        8         1
# ...    ..  ..      ...       ...
# 17350  20  20       81       125
# 17351  20  20       82        22
# 17352  20  20       83         1
# 17353  20  20       84        23
# 17354  20  20       85         1
#
# [17355 rows x 4 columns]

# %%
city = city.sort_values(by = ["x", "y", "category"], ignore_index = True)
city
# Out:
#         x   y category POI_count
# 0       1   1        4        21
# 1       1   1        5         9
# 2       1   1        6         1
# 3       1   1        7         1
# 4       1   1        8         1
# ...    ..  ..      ...       ...
# 17350  20  20       81       125
# 17351  20  20       82        22
# 17352  20  20       83         1
# 17353  20  20       84        23
# 17354  20  20       85         1
#
# [17355 rows x 4 columns]

# %%
compressed = {"x" : [], "y" : []}
for i in range(1, 86):
    compressed[i] = []

compressed_df = pd.DataFrame(compressed)

checked = []

for x, y in zip(city["x"], city["y"]):
    if (x, y) in checked:
        continue

    filtered_vector = city[(city["x"] == x) & (city["y"] == y)]
    red_vector = [0] * 85

    for idx, row in filtered_vector.iterrows():
        category = row["category"]
        poi_count = row["POI_count"]
        
        red_vector[category - 1] = poi_count

    red_vector_softmax = softmax(red_vector)
    compressed_row = [x, y]
    compressed_row.extend(red_vector_softmax)

    compressed_df.loc[len(compressed_df)] = compressed_row

    checked.append((x, y))

# %%
compressed_df["x"] = compressed_df["x"].astype("int")
compressed_df["y"] = compressed_df["y"].astype("int")
compressed_df
# Out:
#       x   y             1             2             3             4  \
# 0     1   1  1.589134e-28  1.589134e-28  1.589134e-28  2.095775e-19
# 1     1   2  3.221340e-27  8.756511e-27  3.221340e-27  2.610279e-23
# 2     1   3  2.483533e-23  9.136408e-24  2.483533e-23  5.470346e-19
# 3     1   4  1.688912e-48  1.688912e-48  4.590938e-48  1.333615e-34
# 4     1   5  2.639245e-66  2.406680e-69  1.778309e-68  2.227089e-39
# ..   ..  ..           ...           ...           ...           ...
# 332  20  16  5.949087e-05  5.949087e-05  5.949087e-05  5.949087e-05
# 333  20  17  2.061118e-09  2.061118e-09  2.061118e-09  1.522972e-08
# 334  20  18  3.139133e-17  3.139133e-17  3.139133e-17  4.658886e-15
# 335  20  19  2.748785e-43  2.748785e-43  5.521082e-42  4.780892e-25
# 336  20  20  3.817497e-54  5.166421e-55  1.404379e-54  1.011221e-43
#
#                 5             6             7             8  ...  \
# 0    1.287689e-24  4.319715e-28  4.319715e-28  4.319715e-28  ...
# 1    6.470235e-26  8.756511e-27  8.756511e-27  3.221340e-27  ...
# 2    1.001929e-20  9.136408e-24  1.355963e-21  2.483533e-23  ...
# 3    2.506567e-46  1.688912e-48  1.247946e-47  4.590938e-48  ...
# 4    1.580225e-61  2.406680e-69  7.174211e-66  4.833945e-68  ...
# ..            ...           ...           ...           ...  ...
# 332  5.949087e-05  5.949087e-05  5.949087e-05  5.949087e-05  ...
# 333  2.061118e-09  2.061118e-09  2.061118e-09  2.061118e-09  ...
# 334  8.533047e-17  3.139133e-17  8.533047e-17  3.139133e-17  ...
# 335  3.305700e-37  7.471971e-43  5.521082e-42  5.521082e-42  ...
# 336  7.667648e-53  1.404379e-54  3.817497e-54  5.166421e-55  ...
#
#                76            77            78            79            80  \
# 0    7.709926e-20  4.319715e-28  3.191861e-27  6.676287e-03  4.319715e-28
# 1    2.862519e-20  8.756511e-27  6.470235e-26  1.154822e-17  1.758792e-25
# 2    4.432667e-15  9.136408e-24  1.355963e-21  4.736959e-02  3.685890e-21
# 3    4.780892e-25  4.590938e-48  3.392270e-47  6.914399e-13  3.720075e-44
# 4    4.905489e-35  1.314003e-67  3.916986e-64  3.532193e-24  1.314003e-67
# ..            ...           ...           ...           ...           ...
# 332  4.395813e-04  5.949087e-05  5.949087e-05  4.395813e-04  1.617129e-04
# 333  5.602700e-09  2.061118e-09  2.061118e-09  2.061118e-09  2.061118e-09
# 334  4.658886e-15  3.139133e-17  8.533047e-17  9.357622e-14  8.533047e-17
# 335  2.170522e-29  5.521082e-42  3.014408e-40  9.357622e-14  1.500786e-41
# 336  3.720076e-44  3.817497e-54  7.667648e-53  6.470235e-26  5.665668e-52
#
#                81            82            83            84            85
# 0    2.763941e-10  3.838546e-21  4.319715e-28  4.737142e-25  1.589134e-28
# 1    1.522998e-08  3.532629e-24  6.470235e-26  1.053062e-20  8.756511e-27
# 2    8.676042e-04  1.486994e-18  1.835097e-22  3.275323e-14  9.136408e-24
# 3    9.999998e-01  8.985825e-37  1.852116e-45  2.442600e-36  4.590938e-48
# 4    1.233946e-04  3.817026e-54  5.301064e-65  6.375083e-59  1.778309e-68
# ..            ...           ...           ...           ...           ...
# 332  2.400033e-02  4.395813e-04  1.617129e-04  5.949087e-05  5.949087e-05
# 333  1.125332e-07  1.522972e-08  2.061118e-09  2.061118e-09  2.061118e-09
# 334  4.139937e-08  8.533047e-17  8.533047e-17  2.319523e-16  3.139133e-17
# 335  9.999999e-01  3.625141e-34  8.194012e-40  6.639676e-36  2.031092e-42
# 336  1.000000e+00  1.852117e-45  1.404379e-54  5.034575e-45  1.404379e-54
#
# [337 rows x 87 columns]

# %%
matrix_768x85 = torch.load("phrase_embeddings.pt")
vectors = compressed_df.drop(columns = ["x", "y"])
orange_vector_dict = {}

for idx, row in vectors.iterrows():
    vector_85x1 = torch.tensor(list(row))
    orange_vector = torch.matmul(vector_85x1, matrix_768x85)
    orange_vector_list = orange_vector.tolist()
    
    for i in range(len(orange_vector_list)):
        tostring = str(i + 1)
        key = "orange" + tostring
        
        if orange_vector_dict.get(key, "na") == "na":
            orange_vector_dict[key] = [orange_vector_list[i]]
        else:
            orange_vector_dict[key].append(orange_vector_list[i])
# Out:
# /var/folders/xz/6hxqmsn50x7dlkq5rt6sldv00000gn/T/ipykernel_62148/654530320.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   matrix_768x85 = torch.load("phrase_embeddings.pt")

# %%
orange_vector_df = pd.DataFrame(orange_vector_dict)
final_df = pd.concat([compressed_df, orange_vector_df], axis = 1)
final_df.to_csv("cityA_red_orange.csv", index = False)
